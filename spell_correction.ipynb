# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("Indonesian_corpus.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 537892 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 22611 unique words in the vocabulary

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
word_counts = Counter(words)
print(word_counts["saya"])
# Out:
# 221

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["saya"])
# Out:
# 0.00041086314724889014

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("sampah"))
# Out:
# [('', 'sampah'), ('s', 'ampah'), ('sa', 'mpah'), ('sam', 'pah'), ('samp', 'ah'), ('sampa', 'h'), ('sampah', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("sampah"))
# Out:
# ['ampah', 'smpah', 'sapah', 'samah', 'samph', 'sampa']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("sampah"))
# Out:
# ['asmpah', 'smapah', 'sapmah', 'samaph', 'sampha']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("sampah"))
# Out:
# ['aampah', 'bampah', 'campah', 'dampah', 'eampah', 'fampah', 'gampah', 'hampah', 'iampah', 'jampah', 'kampah', 'lampah', 'mampah', 'nampah', 'oampah', 'pampah', 'qampah', 'rampah', 'sampah', 'tampah', 'uampah', 'vampah', 'wampah', 'xampah', 'yampah', 'zampah', 'sampah', 'sbmpah', 'scmpah', 'sdmpah', 'sempah', 'sfmpah', 'sgmpah', 'shmpah', 'simpah', 'sjmpah', 'skmpah', 'slmpah', 'smmpah', 'snmpah', 'sompah', 'spmpah', 'sqmpah', 'srmpah', 'ssmpah', 'stmpah', 'sumpah', 'svmpah', 'swmpah', 'sxmpah', 'sympah', 'szmpah', 'saapah', 'sabpah', 'sacpah', 'sadpah', 'saepah', 'safpah', 'sagpah', 'sahpah', 'saipah', 'sajpah', 'sakpah', 'salpah', 'sampah', 'sanpah', 'saopah', 'sappah', 'saqpah', 'sarpah', 'saspah', 'satpah', 'saupah', 'savpah', 'sawpah', 'saxpah', 'saypah', 'sazpah', 'samaah', 'sambah', 'samcah', 'samdah', 'sameah', 'samfah', 'samgah', 'samhah', 'samiah', 'samjah', 'samkah', 'samlah', 'sammah', 'samnah', 'samoah', 'sampah', 'samqah', 'samrah', 'samsah', 'samtah', 'samuah', 'samvah', 'samwah', 'samxah', 'samyah', 'samzah', 'sampah', 'sampbh', 'sampch', 'sampdh', 'sampeh', 'sampfh', 'sampgh', 'samphh', 'sampih', 'sampjh', 'sampkh', 'samplh', 'sampmh', 'sampnh', 'sampoh', 'sampph', 'sampqh', 'samprh', 'sampsh', 'sampth', 'sampuh', 'sampvh', 'sampwh', 'sampxh', 'sampyh', 'sampzh', 'sampaa', 'sampab', 'sampac', 'sampad', 'sampae', 'sampaf', 'sampag', 'sampah', 'sampai', 'sampaj', 'sampak', 'sampal', 'sampam', 'sampan', 'sampao', 'sampap', 'sampaq', 'sampar', 'sampas', 'sampat', 'sampau', 'sampav', 'sampaw', 'sampax', 'sampay', 'sampaz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("sampah"))
# Out:
# ['asampah', 'bsampah', 'csampah', 'dsampah', 'esampah', 'fsampah', 'gsampah', 'hsampah', 'isampah', 'jsampah', 'ksampah', 'lsampah', 'msampah', 'nsampah', 'osampah', 'psampah', 'qsampah', 'rsampah', 'ssampah', 'tsampah', 'usampah', 'vsampah', 'wsampah', 'xsampah', 'ysampah', 'zsampah', 'saampah', 'sbampah', 'scampah', 'sdampah', 'seampah', 'sfampah', 'sgampah', 'shampah', 'siampah', 'sjampah', 'skampah', 'slampah', 'smampah', 'snampah', 'soampah', 'spampah', 'sqampah', 'srampah', 'ssampah', 'stampah', 'suampah', 'svampah', 'swampah', 'sxampah', 'syampah', 'szampah', 'saampah', 'sabmpah', 'sacmpah', 'sadmpah', 'saempah', 'safmpah', 'sagmpah', 'sahmpah', 'saimpah', 'sajmpah', 'sakmpah', 'salmpah', 'sammpah', 'sanmpah', 'saompah', 'sapmpah', 'saqmpah', 'sarmpah', 'sasmpah', 'satmpah', 'saumpah', 'savmpah', 'sawmpah', 'saxmpah', 'saympah', 'sazmpah', 'samapah', 'sambpah', 'samcpah', 'samdpah', 'samepah', 'samfpah', 'samgpah', 'samhpah', 'samipah', 'samjpah', 'samkpah', 'samlpah', 'sammpah', 'samnpah', 'samopah', 'samppah', 'samqpah', 'samrpah', 'samspah', 'samtpah', 'samupah', 'samvpah', 'samwpah', 'samxpah', 'samypah', 'samzpah', 'sampaah', 'sampbah', 'sampcah', 'sampdah', 'sampeah', 'sampfah', 'sampgah', 'samphah', 'sampiah', 'sampjah', 'sampkah', 'samplah', 'sampmah', 'sampnah', 'sampoah', 'samppah', 'sampqah', 'samprah', 'sampsah', 'samptah', 'sampuah', 'sampvah', 'sampwah', 'sampxah', 'sampyah', 'sampzah', 'sampaah', 'sampabh', 'sampach', 'sampadh', 'sampaeh', 'sampafh', 'sampagh', 'sampahh', 'sampaih', 'sampajh', 'sampakh', 'sampalh', 'sampamh', 'sampanh', 'sampaoh', 'sampaph', 'sampaqh', 'samparh', 'sampash', 'sampath', 'sampauh', 'sampavh', 'sampawh', 'sampaxh', 'sampayh', 'sampazh', 'sampaha', 'sampahb', 'sampahc', 'sampahd', 'sampahe', 'sampahf', 'sampahg', 'sampahh', 'sampahi', 'sampahj', 'sampahk', 'sampahl', 'sampahm', 'sampahn', 'sampaho', 'sampahp', 'sampahq', 'sampahr', 'sampahs', 'sampaht', 'sampahu', 'sampahv', 'sampahw', 'sampahx', 'sampahy', 'sampahz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("sampah"))
# Out:
# {'lsampah', 'saepah', 'samsah', 'sabmpah', 'scmpah', 'smmpah', 'sdampah', 'samzpah', 'wampah', 'sahmpah', 'sampaw', 'sympah', 'satpah', 'sampkh', 'spampah', 'sempah', 'sampahs', 'sawpah', 'hsampah', 'samcah', 'sampaih', 'samjah', 'samparh', 'sampaa', 'samxah', 'sgampah', 'mampah', 'sapah', 'sampkah', 'tampah', 'ssampah', 'sampcah', 'sxmpah', 'sampazh', 'sammah', 'sampxh', 'sampch', 'sampath', 'sgmpah', 'csampah', 'sampbh', 'sampauh', 'samfpah', 'samppah', 'sampiah', 'sampahl', 'sampzh', 'satmpah', 'sampar', 'samipah', 'jampah', 'msampah', 'vampah', 'sampahd', 'samapah', 'sampad', 'samaph', 'salmpah', 'sampdah', 'spmpah', 'samjpah', 'samwah', 'sacpah', 'samlpah', 'sampyah', 'sbmpah', 'sampadh', 'zsampah', 'saapah', 'salpah', 'xsampah', 'sawmpah', 'saympah', 'samph', 'sampoh', 'sampai', 'rsampah', 'sampal', 'sampaq', 'skampah', 'sampeah', 'sompah', 'srmpah', 'sampoah', 'sampanh', 'sampahp', 'sampan', 'samplh', 'sampaeh', 'sampay', 'sampax', 'sampxah', 'sacmpah', 'sameah', 'sampbah', 'sarpah', 'sampvh', 'samwpah', 'sampwah', 'saqmpah', 'samyah', 'swampah', 'sampah', 'eampah', 'samplah', 'safmpah', 'samtah', 'shampah', 'sagmpah', 'campah', 'saumpah', 'saipah', 'samypah', 'saupah', 'sampnah', 'samspah', 'sakpah', 'saimpah', 'ampah', 'siampah', 'samoah', 'sampsh', 'saqpah', 'sampfh', 'sampalh', 'sapmah', 'sampyh', 'samphh', 'sappah', 'sampmah', 'sampak', 'samfah', 'sampaz', 'sampth', 'sampash', 'sakmpah', 'saempah', 'sampaho', 'sampahb', 'sampahi', 'sampae', 'samdpah', 'sjampah', 'vsampah', 'sampawh', 'sampaxh', 'sampvah', 'smapah', 'sampach', 'sampas', 'osampah', 'sampahz', 'samptah', 'sampfah', 'sampahg', 'sammpah', 'iampah', 'pampah', 'samaah', 'scampah', 'psampah', 'sampamh', 'sarmpah', 'sampahw', 'slampah', 'sfmpah', 'sampaj', 'sampahm', 'samprh', 'samlah', 'sampahv', 'oampah', 'samepah', 'sampsah', 'szampah', 'jsampah', 'asmpah', 'hampah', 'samuah', 'sabpah', 'sampao', 'sampgah', 'samphah', 'sampuah', 'ssmpah', 'sambpah', 'sbampah', 'sampajh', 'sampahe', 'sazmpah', 'sampha', 'esampah', 'wsampah', 'samprah', 'sampahc', 'smpah', 'shmpah', 'sasmpah', 'uampah', 'sampa', 'sampaf', 'sampgh', 'ksampah', 'sampph', 'sapmpah', 'samkah', 'gsampah', 'sampaph', 'sampuh', 'sampam', 'samqah', 'bampah', 'sqampah', 'skmpah', 'sampjah', 'sadpah', 'rampah', 'asampah', 'slmpah', 'zampah', 'sampahq', 'samrah', 'sumpah', 'ysampah', 'savpah', 'snampah', 'dsampah', 'samhah', 'samopah', 'sampwh', 'sampab', 'sagpah', 'sampqh', 'usampah', 'samnah', 'seampah', 'sampau', 'nampah', 'sadmpah', 'sampaht', 'qampah', 'sampap', 'sajmpah', 'samhpah', 'sampac', 'fampah', 'sambah', 'samiah', 'sqmpah', 'sanpah', 'sampahr', 'yampah', 'xampah', 'saxmpah', 'sampahy', 'saspah', 'samdah', 'sampahf', 'sfampah', 'savmpah', 'sanmpah', 'samvah', 'sampabh', 'samgah', 'szmpah', 'safpah', 'sampav', 'sampih', 'sampdh', 'sampavh', 'sampayh', 'sampakh', 'lampah', 'syampah', 'sahpah', 'saompah', 'samnpah', 'svmpah', 'samkpah', 'samcpah', 'sampaha', 'gampah', 'sjmpah', 'samrpah', 'sampmh', 'saxpah', 'qsampah', 'sampagh', 'svampah', 'sajpah', 'nsampah', 'sampahn', 'sampat', 'sampjh', 'samah', 'samqpah', 'sdmpah', 'sampahx', 'samzah', 'sampafh', 'stmpah', 'sampaah', 'sampaoh', 'sampahh', 'simpah', 'sxampah', 'kampah', 'saopah', 'sampnh', 'samgpah', 'sampaqh', 'samupah', 'sampzah', 'bsampah', 'soampah', 'sampag', 'sazpah', 'saampah', 'samtpah', 'isampah', 'suampah', 'samvpah', 'samxpah', 'sampeh', 'sampahj', 'sampahk', 'swmpah', 'snmpah', 'stampah', 'fsampah', 'srampah', 'sampqah', 'sampahu', 'smampah', 'tsampah', 'dampah', 'saypah', 'aampah'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("sampah"))
# Out:
# {'samptadh', 'samhpth', 'sabmpaph', 'ssampahw', 'sxmpahe', 'saimpaf', 'saitah', 'spamrah', 'sakmyah', 'snampiah', 'sacmphh', 'sqdmpah', 'sadpfah', 'saomdpah', 'saqpath', 'sagnah', 'suampvah', 'sakmpgh', 'samkuh', 'sagpaho', 'tampak', 'sambpqah', 'smamfpah', 'sacmpaq', 'zssampah', 'qsamvah', 'bgmpah', 'shampbh', 'sxamgah', 'samfpazh', 'osamzah', 'mamaah', 'bmsampah', 'sacpaho', 'xamph', 'samqpawh', 'fampph', 'satpah', 'samtvh', 'kampfh', 'sampshah', 'sambahv', 'fsamnah', 'sampty', 'sxmepah', 'saxqah', 'safzmpah', 'campan', 'oampkh', 'asmpahb', 'samkoah', 'waympah', 'gampaeh', 'sapmauh', 'sxlampah', 'saompagh', 'samparp', 'sawpfh', 'asaumpah', 'sopampah', 'syampha', 'sxmvpah', 'skmkah', 'samaparh', 'sammmpah', 'saypph', 'qsampahe', 'sampzazh', 'sampamha', 'saumph', 'sbampuah', 'fsempah', 'sampcaz', 'swmfpah', 'saqpav', 'sampkhy', 'samcpae', 'sapmahg', 'samsrh', 'rsamapah', 'evsampah', 'samspahd', 'sktpah', 'saumpazh', 'wampkah', 'slampiah', 'sarpach', 'fampap', 'sameakh', 'samjvah', 'wajpah', 'saqrmpah', 'samepaxh', 'scampha', 'safmspah', 'isampaa', 'sbkampah', 'samodh', 'samcpahb', 'sseampah', 'sampkadh', 'ampch', 'saqmmpah', 'smamoah', 'szamepah', 'sajpph', 'babpah', 'syampaqh', 'sampawp', 'skpmah', 'saqpjah', 'sazpaah', 'samwsh', 'sanpsh', 'sanhmpah', 'samspahw', 'stamdpah', 'sampsamh', 'saimpaq', 'sasmpawh', 'saopzh', 'sbampab', 'salmpabh', 'uampakh', 'sappmah', 'simpan', 'sabmpahg', 'salmpahb', 'sajpax', 'samxahe', 'samcpgh', 'satpadh', 'zampaph', 'aqampah', 'szampdah', 'samapahx', 'sampyvh', 'satmopah', 'sompach', 'safpae', 'vsampuh', 'sxampzh', 'sfampaha', 'ampad', 'samtpanh', 'sdampahs', 'seyampah', 'asampaht', 'sbmpgah', 'saipjh', 'samuath', 'saompaht', 'sompaih', 'sampwfh', 'samtaxh', 'stambah', 'saepmh', 'sampamht', 'ssaopah', 'soamepah', 'lsampahw', 'sbmpsh', 'sampaet', 'sapahq', 'qsamwpah', 'saqpawh', 'sajmpjh', 'savmgpah', 'msampcah', 'stlampah', 'saemhah', 'damnah', 'samhpakh', 'samway', 'zsampahu', 'asvpah', 'sxampawh', 'xamwah', 'safmpajh', 'samnahx', 'semgpah', 'sampifah', 'sarmpsah', 'hampahy', 'smapagh', 'sbempah', 'samphac', 'spamlpah', 'sabmplh', 'sammbh', 'qsampqh', 'samaprah', 'snmpanh', 'stamgpah', 'satnmpah', 'sakiah', 'sycpah', 'csamwah', 'swampahy', 'uisampah', 'ntsampah', 'svlpah', 'sadpad', 'tsampahv', 'hampqh', 'sadmpxh', 'zaypah', 'samnwah', 'samopar', 'suampahj', 'satpxh', 'tsaampah', 'sdmpwh', 'sampatd', 'ogsampah', 'samprrah', 'sampayj', 'samijpah', 'bamlpah', 'cumpah', 'lcsampah', 'saumpbah', 'samdpaqh', 'eampahe', 'slspah', 'sammhh', 'sjampayh', 'sampeahf', 'bsafmpah', 'sbampa', 'qsampai', 'vamrah', 'samfhpah', 'wsampzah', 'samjahr', 'sambpaf', 'usampahr', 'sampakgh', 'qsaxpah', 'hamfpah', 'esaopah', 'sampuahu', 'uammpah', 'sampafhc', 'saepach', 'swakpah', 'samlpahb', 'hampaht', 'saymiah', 'saypaph', 'suampqah', 'rsamzpah', 'sgamfah', 'spzpah', 'suampahl', 'zaapah', 'soampayh', 'saodmpah', 'sfmpcah', 'skmpadh', 'sdampac', 'sarpahz', 'samafh', 'salmpaah', 'samragh', 'yaympah', 'saxmjpah', 'sbmaph', 'samohpah', 'sazmpzh', 'pamnpah', 'syamspah', 'sahpaw', 'slmpazh', 'sampahex', 'wfsampah', 'savpach', 'sampnauh', 'samqpahf', 'vsampahp', 'sampsash', 'saxmpal', 'yamphah', 'lammpah', 'salmpvh', 'savpafh', 'spmrah', 'samwlpah', 'tamplah', 'sammahi', 'shambah', 'asmpuh', 'sazpaph', 'nampxh', 'rampam', 'sxamvah', 'samddah', 'nsapmpah', 'jampaw', 'sampaumh', 'sagpeah', 'snmpdh', 'sympuah', 'sakmpyh', 'smampahu', 'lsnampah', 'samtahc', 'sumprh', 'sampyae', 'saqpahe', 'jsawmpah', 'samipahu', 'seamxah', 'sathmpah', 'sxiampah', 'sampxhr', 'sadmpahj', 'sapmah', 'swampeh', 'qksampah', 'msamphh', 'sampoeah', 'sampteah', 'spmpiah', 'sampansh', 'sakpahf', 'sarmppah', 'samphqa', 'sampbay', 'yfampah', 'samhwah', 'savmlpah', 'sgmpxh', 'sqampahm', 'yxampah', 'wsampam', 'sampwahk', 'saumgpah', 'sqjpah', 'vampay', 'sanmpadh', 'svmlah', 'nampaq', 'smarah', 'samenpah', 'snampath', 'sampaihp', 'sazmpahd', 'seampahv', 'sampdabh', 'smamzah', 'gampau', 'satpayh', 'samruh', 'samvash', 'stmpab', 'sampzhr', 'sumpamh', 'yampeh' ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "samaph"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")
# Out:
# [('sampah', 3.718218527139277e-06)]
# sampah is suggested for samaph

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters] 

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("Indonesian_corpus.txt")

# %%
checker.check("sampah")
# Out:
# [('sampai', 0.0004350315676752954),
#  ('sampah', 3.718218527139277e-06),
#  ('sumpah', 3.718218527139277e-06)]
